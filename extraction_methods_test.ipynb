# %% [markdown]
# # Testing Various Extraction Methods
#
# 1. PIL Image tags
# 2. Using the [Zeiss Metadata TIFF Reader](https://github.com/cgohlke/tifffile)
# 3. Using Hyperspy

# %%
# imgPath = '/Users/elias/Desktop/MatWerk_Projects/SEMtestImages/P10_ID01#4-PtPd_080.tif'
imgPath = '/Users/elias/Desktop/MatWerk_Projects/SEMtestImages/Au-Gr_06.tif'

# %% [markdown]
# # PIL Image Tags

# %%
from PIL import Image
from PIL.ExifTags import TAGS

# %%
image = Image.open(imgPath)
tags  = image.tag_v2

# 34118, 34682

# for tag, value in tags.items():
#     print(f"Tag: {tag}, Value: {value}")
#     print('\n' + '-'*50 + '\n')

# %%
def pil_extract(file_path) -> dict:
    try:
        with Image.open(file_path) as img:
            # Extract metadata from tags 34118 and 34682
            tags_to_check = [34118, 34682]
            metadata_strs = [img.tag_v2.get(tag) for tag in tags_to_check if img.tag_v2.get(tag)]
                
            # Process the metadata strings
            metadata = {}
            for metadata_str in metadata_strs:
                lines = metadata_str.split("\n")
                for line in lines:
                    if "=" in line:
                        key, value = line.split("=", 1)
                        key = key.strip()
                        values = tuple(val.strip() for val in value.split())
                        if len(values) == 1:
                            metadata[key] = values[0]
                        else:
                            metadata[key] = values
                    elif ":" in line:
                        key, value = line.split(":", 1)
                        key = key.strip()
                        values = tuple(val.strip() for val in value.split())
                        if len(values) == 1:
                            metadata[key] = values[0]
                        else:
                            metadata[key] = values
            return metadata

    except Exception as e:
        return {"error": str(e)}

# %%
PIL_md = pil_extract(imgPath)

len(PIL_md)
# Out:
# 721

# %% [markdown]
# ## Zeiss Metadata Reader

# %%
import zeisstiffmeta as ztm
def zeiss_extract(file_path: str) -> dict:
    """
    Extracts metadata using the Zeiss TIFF reader method.

    Args:
        file_path (str): Path to the TIFF file.

    Returns:
        dict: Extracted metadata as a Python dictionary.
    """
    try:
        # Extract metadata from the TIFF file using zeiss_tiff_meta
        metadata_list = ztm.zeiss_meta(file_path)
        
        # Convert the metadata list to a dictionary
        metadata = ztm.meta_to_dict_all(metadata_list)
        
        return metadata

    except Exception as e:
        return {"error": str(e)}

# %%
# zeiss_md = zeiss_extract(imgPath)
# zeiss_md.pop('xpts')
# zeiss_md.pop('ypts')
# zeiss_md.pop('height')
# zeiss_md.pop('width')

# %% [markdown]
# ## Hyperspy Method

# %%
import hyperspy.api as hs

f = hs.load(imgPath)

# hs_md_raw = f.original_metadata.as_dictionary().get('fei_metadata', {})
hs_md_raw = f.original_metadata.as_dictionary().get('CZ_SEM', {})
hs_md_raw.pop('', None)
# Out:
# (0,
#  0,
#  0,
#  9.183126e-10,
#  399850.2,
#  6,
#  5000.0,
#  2.25,
#  2e-07,
#  0.004021607,
#  1,
#  9.183126e-10,
#  399850.2,
#  6,
#  5000.0,
#  2.25,
#  2e-07,
#  0.004021607,
#  2,
#  3.696236e-06,
#  99.3409,
#  6,
#  0.0,
#  2.25,
#  2e-07,
#  0.00246,
#  3,
#  3.696236e-06,
#  99.3409,
#  6,
#  0.0,
#  2.25,
#  2e-07,
#  0.00246,
#  724)

# %%
def flatten_dict(d):
    """
    Flattens a nested dictionary by removing the top-level keys.
    
    Args:
        d (dict): The input nested dictionary.
        
    Returns:
        dict: The flattened dictionary with top-level keys removed.
    """
    flattened = {}
    for k, v in d.items():
        if isinstance(v, dict):
            flattened.update(flatten_dict(v))
        else:
            flattened[k] = v
    return flattened

# %%
hs_md = flatten_dict(hs_md_raw)
print(f'Length of HS metadata: {len(hs_md)}, Length of PIL metadata: {len(PIL_md)}')
# Out:
# Length of HS metadata: 722, Length of PIL metadata: 721

# %%
hyperspy_keys = []
for item in hs_md:
    hyperspy_keys.append(hs_md[item][0])
    
hyperspy_keys
# Out:
# ['Vent inhibit',
#  'OptiBeam Mode',
#  'VP Aperture',
#  'Input LUT Mode',
#  'BSD Autolevel Mode',
#  'Recipe',
#  'Signal B',
#  'BSD Fast',
#  'Opt.Aperture',
#  'Track Z',
#  'EPSE Electrode',
#  'C3 Rot Corrn.',
#  'Fisheye Mode',
#  'Stage Tilt',
#  'Argon Gun',
#  'Column Isolated',
#  'Mixing',
#  'Flood Gun Mode Target',
#  'STEM Gain',
#  'High Current',
#  'Dwell Time',
#  'SmartImage Noise Reduction',
#  'Right Frozen',
#  'Flood Gun Blanked',
#  'Fast Mode',
#  'Compuc. Mode',
#  'Anode Aperture Changer',
#  'GIS Shutdown State',
#  'FIB Column',
#  'Stage Tilted',
#  'FIB Suppressor is',
#  'VPSE detector',
#  'Crosshairs',
#  'Double Deflection State',
#  'WDX Gate Valve posn',
#  'HE-SE2 Fitted',
#  'EP Gas',
#  'Condenser Normal',
#  'Invert B',
#  'BSD Gain',
#  'FIB Gun Valve',
#  'Aperture',
#  'Electron Counting',
#  'Saturate at',
#  'Stage Angle corrn.',
#  'Store resolution',
#  'Field Mode',
#  'CoolStage Type',
#  'Best Aperture',
#  'Flood Gun Actual Mode',
#  'STEM Auto',
#  'Stage Initialised',
#  'GIS Channel with CC',
#  'Display',
#  'Flood Gun Fitted',
#  'BSD Mode',
#  'FIB Mode',
#  'Nano Tips',
#  'BSD Invert',
#  'MGS Evacuation State',
#  'Use End Point Detection',
#  'Mains Sync',
#  'FIB preparation for pneumatic',
#  'Image',
#  'Filament Type',
#  'Sample Holder',
#  'FIB Scan',
#  'Beam Blanked',
#  'CC Type',
#  'BSD',
#  'Image saved',
#  'Mag Range',
#  'User Align',
#  'Zone',
#  'Filament blown',
#  'Humidity Valve',
#  'Peltier Photo',
#  'Control',
#  'Invert A',
#  'Remoting Target',
#  'Stage Is',
#  'FIB Present',
#  'Peltier Type',
#  'Signal A Z0',
#  'Freeze on',
#  'FIB Blanked',
#  'Beam deceleration',
#  'EPSE Gain',
#  'End Detection',
#  'Vac comms fail',
#  'BSD Auto Range',
#  'Pneumatic Device in use',
#  'FIB Wide View',
#  'Anode Spacer',
#  'Reference Mag',
#  'Stage Bias',
#  'User Calibration',
#  'Safe STEM Valid',
#  'Q5',
#  'SCD Gain',
#  'All Zones',
#  'Signal A',
#  'EHT tripped',
#  'Flood State',
#  'Extractor Trip',
#  'BSD Fast Scan',
#  'InlensDuo Mode',
#  'Auto BC',
#  'Flood Gun Remoting Actual',
#  'Signal A Z1',
#  'Variable stage bias fitted',
#  'EPSE Auto Range',
#  'Stage comms fail',
#  'OptiProbe',
#  'C.L.S.Valve',
#  'New Filament',
#  'Image Detect',
#  'Custom Holder',
#  'Zoom',
#  'SCD Auto Range',
#  'Ext.Scan Control',
#  'Detector',
#  'EHT spurious reset',
#  'STEM Q4',
#  'Extractor Target State',
#  'Jazz Gain',
#  'Monitor',
#  'Freeze',
#  'FIB Extractor Conflict',
#  'Beam deceleration carousel',
#  'EPSE Bandwidth',
#  'Stage bias low voltage',
#  'Stig Balance',
#  'Frame Grabber',
#  'VPSE-G3 Fitted',
#  'Q1',
#  'FIB Lock Mags',
#  'Freeze Blanks',
#  'Windowing',
#  'Partial Vent on Standby',
#  'SCD Bandwidth',
#  'Calibration',
#  'STEM Q1',
#  'EHT Vac ready',
#  'STEM Q5',
#  'Flood Gun Extractor Actual State',
#  'full service bakeout',
#  'Water OK',
#  'Low Mag',
#  'Venting inhibited',
#  'FIB Probe',
#  'Display LUT mode',
#  'OptiBeam Is',
#  'ScanGen Type',
#  'Final Lens',
#  'EHT Comms Fail',
#  'Scan Gen',
#  'Num. Regions',
#  'FIB Error',
#  'GIS Heating Status Channel 1',
#  'BSD Bandwidth',
#  'Q2',
#  'Dyn.Focus',
#  'Supervisor',
#  'Colour Mode',
#  'Tilt Corrn.',
#  'Spot',
#  'EP Aperture',
#  'Noise reduction for fast scanspeeds',
#  'SESI Mode',
#  'Fish-Eye Fitted',
#  'STEM Q2',
#  'Pix Size state',
#  'Beam Blanker Mode',
#  'FIB Image Probe',
#  'Argon Mill',
#  'FIB Mag Range',
#  'User Level',
#  'Argon Scan',
#  'Chamber Status',
#  'Column',
#  'Large Beam Shift',
#  'Argon MFC Valve',
#  'Contrast Enhanced',
#  'Q3',
#  'Scan Rot',
#  'Sem drift status',
#  'Line Scan',
#  'Signal A Z2',
#  'SCM range',
#  'Flood Gun Type',
#  'STEM Q3',
#  'Mag State',
#  'Go to HV @ Shutdown',
#  'SCM Status',
#  'SI source-hidden',
#  'OptiBeam conjugate',
#  'Flood Gun Status',
#  'VP Optibeam',
#  'Condenser Reversed',
#  'Zone 0',
#  'FIB Milling Probe',
#  'Scint.',
#  'OptiBeam Res Mode',
#  'Jazz Bandwidth',
#  'IGP Enabled',
#  'WDX Gate valve',
#  'Peltier',
#  'Output Reduction',
#  'Q4',
#  'Aperture No.',
#  'Sem',
#  'Scan Orthog',
#  'Channels',
#  'Dual Monitor',
#  'Signal A Z3',
#  'C3 Rotn Sign',
#  'STEM Fast',
#  'Output dev',
#  'User',
#  'FIB Tracking WD',
#  'Flood Gun Interlock',
#  'Low KV Lens',
#  'Zone 1',
#  'CC Status',
#  'FIB Gun State',
#  'Argon Gun is',
#  'Output To',
#  'Column Chamber valve',
#  'Column pumping',
#  'Scan Speed',
#  'All Frozen',
#  'Operating Mode',
#  'GIS Channel',
#  'FIB Imaging',
#  'C3 Reversal',
#  'Vacuum Mode',
#  'Column Mode',
#  'STEM Seg. Mode',
#  'Cal Mode',
#  'Beam State',
#  'Noise Reduction',
#  'OptiBeam',
#  'Vac Status',
#  'Flood Gun Emission target',
#  'FIB Shift Correction Y',
#  'Mag',
#  'Line Time',
#  'FIB Mag fine gain Y',
#  'Spot at Y',
#  'Orthogonality Lower',
#  'Aa 4',
#  'Stage vector X',
#  'Argon Condenser',
#  'Min Mag',
#  'Stage goto R',
#  'VP Target',
#  'EHT Cal@0.1KV',
#  'Pa 7',
#  'V 4',
#  'Stage Delta R',
#  'File No',
#  'ESD Lower Y',
#  'Free WD',
#  'Brightness D',
#  'Field Mode Quadriture',
#  'Tilt Angle',
#  'Mill List Elapsed Time',
#  'Stigmation X',
#  'Pb 3',
#  'Calibrate Mag Upper Y',
#  'Da 2',
#  'Reduced Raster Width',
#  'VPSE G3 Bias',
#  'Stage low Z',
#  'Argon Magnification',
#  'Argon Shift Ratio Y',
#  'Scan X cal.',
#  'Stage high T',
#  'Profile Top',
#  'Mag Gain Cal X',
#  'H 8',
#  'Spacer Thickness',
#  'Stage high R',
#  'FIB Condenser',
#  'Flood Gun Filament Target',
#  'Aperture Align X',
#  'SEM Level @',
#  'Vac Ready @',
#  'C1 Rem',
#  'Slice Width',
#  'Beam Shift Y',
#  'Pa 1',
#  'Tilt Align X',
#  'Stage X+M Rotation',
#  'SmartImage Topography',
#  'Stage at field Y',
#  'Argon Column Angle',
#  'Test No.',
#  'H 2',
#  'Db 1',
#  'Opt. Semi Angle',
#  'FIB Aper.Align X',
#  'FIB Fil I Target',
#  'Drift Max.Pix.Error',
#  'InlensDuo Grid is',
#  'Fisheye Angle',
#  'Contrast A',
#  'Dual Mag Offset Y',
#  'Mag scaling decel',
#  'Shift Amp Upper Gain X',
#  'Holder Length',
#  'Stage fields Y',
#  'FIB Source Lifetime',
#  'Argon Gas Flow is',
#  'Gain A',
#  'Conjugate posn.',
#  'Mag Shift Cal X',
#  'Back Grid',
#  'Suppressor V',
#  'Aperture Align X',
#  'Pb 6',
#  'V 9',
#  'Profile 2 X2',
#  'FIB Mag',
#  'Flood Gun Emission Actual',
#  'FIB Shift Correction X',
#  'I Probe',
#  'FCF Tilt Angle',
#  'FIB Mag fine gain X',
#  'Stage X+M Angle',
#  'Spot at X',
#  'Orthogonality Upper',
#  'Aa 3',
#  'Stage goto Z',
#  'Argon Discharge I is',
#  'Spot Size',
#  'Pa 6',
#  'V 3',
#  'Stage Delta T',
#  'Specimen Height',
#  'ESD Lower X',
#  'FIB Emission I',
#  'FIB Stig Y Centre Y',
#  'Brightness C',
#  'Field Mode Orthog',
#  'Tilt Axis',
#  'Mill List Total Time',
#  'Aperture Posn Y',
#  'Pb 2',
#  'Calibrate Mag Upper X',
#  'Da 1',
#  'EPSE Bias',
#  'Profile width',
#  'Stage low Y',
#  'Argon Beam Shift Y',
#  'Argon Shift Ratio X',
#  'Xtalk21',
#  'Min Extractor V',
#  'H 7',
#  'Stage Centre Y',
#  'FIB Scan Size',
#  'Stig. Cal Y',
#  'FIB Extractor',
#  'Flood Gun Energy Actual',
#  'FIB Stig X Centre Y',
#  'Piezo Goto Y',
#  'FIB Tilt Comp',
#  'C1 Cal',
#  'Slice Y',
#  'Beam Shift X',
#  'Red.Raster Height',
#  'Calibrate Mag Base',
#  'FIB Nudge Step',
#  'Piezo Exchange Y',
#  'Stage at field X',
#  'Argon Acc I is',
#  'Argon Mill Progress',
#  'Area Fraction',
#  'Nominal Fil I',
#  'Gun at Y',
#  'Stage Vector M',
#  'H 1',
#  'Semi Angle',
#  'FIB Scan Rot',
#  'FIB Fil Voltage',
#  'Stage Angle',
#  'InlensDuo Grid',
#  'Fil I Target',
#  'Brightness B',
#  'Dual Mag Offset X',
#  'Shift Amp Lower Offset Y',
#  'Holder Width',
#  'SmartImage Sharpening',
#  'Stage fields X',
#  'FIB Probe Current Actual',
#  'Argon Gas Flow',
#  'Gamma',
#  'Front Grid',
#  'Extractor V',
#  'Gun Align Y',
#  'Max Extractor V',
#  'Pb 5',
#  'V 8',
#  'Profile 2 X1',
#  'FIB Objective',
#  'Flood Gun Extractor Voltage',
#  'Piezo at Y',
#  'Emission Zoom',
#  'Zoom factor',
#  'FIB Working Distance',
#  'Line To Frame Lower',
#  'Aa 2',
#  'Stage goto Y',
#  'Argon Discharge is',
#  'Mix Signal',
#  'CC Pressure',
#  'Pa 5',
#  'V 2',
#  'Stage Delta Z',
#  'ESD Upper Y',
#  'FIB Abs Beam Shift Y',
#  'FIB Suppressor Target',
#  'FIB Stig Y Centre X',
#  'Purge Min',
#  'FIB Column Pressure',
#  'Field Mode Angle',
#  'C3 Rem',
#  'FIB Pixel Size',
#  'Aperture Posn X',
#  'Pb 1',
#  'C3 saved for beam decel',
#  'ESB Grid is',
#  'EHT set maximum',
#  'Stage low X',
#  'Argon Beam Shift X',
#  'Argon XY Ratio',
#  'Frame Ampl Cal.',
#  'Xtalk12',
#  'Liner Target',
#  'H 6',
#  'Stage Centre X',
#  'Stig. Cal X',
#  'FIB Extr.Target',
#  'Flood Gun Energy Target',
#  'FIB Stig X Centre X',
#  'Piezo Goto X',
#  'C2 Lens I',
#  'Mag Comp. Offset',
#  'Slice X',
#  'Gun Tilt Y',
#  'Red.Raster Width',
#  'Scan Rotation Offset Lower',
#  'Piezo Exchange X',
#  'Stage goto field Y',
#  'Argon Extractor is',
#  'Auto C Target',
#  'Offset B',
#  'Align 1 Y',
#  'Beam Offset Y',
#  'White Threshold',
#  'Gun at X',
#  'EO Temp Limit',
#  'Spot X Cal',
#  'FIB Beam Shift Y',
#  'FIB Fil Current',
#  'Scan Orth corrn',
#  'EHT Target',
#  'Mag Cal Actual Height',
#  'Brightness A',
#  'Decl cal 2',
#  'Shift Amp Lower Offset X',
#  'Holder Diameter',
#  'SmartImage Threshold',
#  'Stage scan angle',
#  'FIB Objective Actual',
#  'Argon Objective is',
#  'Line int. count',
#  'Filament Age',
#  'Dual Mag Gain Y',
#  'Stage vector T',
#  'Peltier Temp',
#  'Gun Align X',
#  'EHT Cal@30KV',
#  'Pa 10',
#  'V 7',
#  'Profile 1 X2',
#  'Stage bias Low Volts',
#  'VP LaB6 Limit',
#  'FIB EHT',
#  'Humidity Target',
#  'Piezo at X',
#  'Line To Frame Upper',
#  'Aa 1',
#  'Reduced Raster Y',
#  'Laser Illumination',
#  'Stage goto X',
#  'Gun Vacuum',
#  'Argon Discharge',
#  'Signal',
#  'Line Avg.Count',
#  'Beam Time',
#  'Cursor Height',
#  'Profile Width 2',
#  'V 1',
#  'Stage Delta Y',
#  'Probe Cal Factor',
#  'ESD Upper X',
#  'FIB Abs Beam Shift X',
#  'FIB Drift Y',
#  'Purge Max',
#  'FIB Heating Limit',
#  'C3 Cal',
#  'Line Counter',
#  'Aperture Size',
#  'Pa 4',
#  'wd saved for beam decel',
#  'Liner Cal @ 10KV',
#  'Beam Current',
#  'Stage high Z',
#  'Convertor Voltage',
#  'Argon Mag Factor',
#  'Mag Z1',
#  'Suppressor V Target',
#  'H 5',
#  'Compu. Height',
#  'FIB Aperture Y Actual',
#  'FIB Emission Target',
#  'C1 Lens I',
#  'Mag Comp. Amplitude',
#  'Slice Index',
#  'Gun Tilt X',
#  'Red.Raster Posn Y',
#  'Shift Amp Lower Gain Y',
#  'Holder Height',
#  'Specimen Diameter',
#  'Stage goto field X',
#  'Argon Extractor',
#  'Auto B Target',
#  'Gain B',
#  'Align 1 X',
#  'Beam Offset X',
#  'Black Threshold',
#  'Nominal extractor V',
#  'Aperture at Y',
#  'Stage high M',
#  'EO Temp',
#  'User Max EHT',
#  'CCD Illum.',
#  'FIB Beam Shift X',
#  'Scan Rotation',
#  'FIB Focus',
#  'Fil I (Usermax)',
#  'Mag Cal Actual Width',
#  'Defect ID',
#  'Decl cal 1',
#  'Shift Amp Upper Offset Y',
#  'SmartImage Contrast',
#  'Stage vector Z',
#  'Argon Objective',
#  'Frames to Int.',
#  'Focus',
#  'Stage vector R',
#  'EHT Cal@24KV',
#  'Pa 9',
#  'V 6',
#  'Profile 1 X1',
#  'HRRU No.',
#  'FIB EHT Target',
#  'Humidity',
#  'ESB Grid Max',
#  'Contrast D',
#  'Mill Item Elapsed Time',
#  'Beam deceleration Volts',
#  'Calibrate Mag Lower Y',
#  'Da 4',
#  'FIB Condenser actual',
#  'Argon Energy is',
#  'Specimen I',
#  'Photo No.',
#  'Field Overlap',
#  'Spot signal',
#  'Cursor Width',
#  'Profile Width 1',
#  'H 10',
#  'Stage Delta X',
#  'Compu. Tilt Error',
#  'FIB Drift X',
#  'Purge cycles',
#  'C3 Lens I',
#  'EPD Low Limit',
#  'C2 Rem',
#  'Slice Angle',
#  'Zoom Posn Y',
#  'Pa 3',
#  'Clip Limit',
#  'Liner cal @ 100V',
#  'Pixel Size',
#  'Stage high Y',
#  'Collector Voltage',
#  'Argon Pixel Size',
#  'Mag Z0',
#  'Focus scan min',
#  'Extractor V Target',
#  'H 4',
#  'Image Pixel Size',
#  'FIB Aperture X Actual',
#  'FIB Suppressor',
#  'Drift Max Tries',
#  'Beam Shift Align Y',
#  'Brightness',
#  'Fisheye quadriture',
#  'Gun Shift Y',
#  'Red.Raster Posn X',
#  'Shift Amp Lower Gain X',
#  'Stage field size Y',
#  'Argon V Int is',
#  'Contrast',
#  'Height',
#  'EHT Set minimum',
#  'Ext I Monitor',
#  'Aperture at X',
#  'Stage low M',
#  'FCF Setting',
#  'Db 4',
#  'FIB Stig Y',
#  'Frame Counter',
#  'Flood Gun Filament Actual',
#  'EP Target',
#  'WD',
#  'HSync delay',
#  'Cycle Time',
#  'FIB Gun Pressure',
#  'Shift Amp Upper Offset X',
#  'Compu. Tilt Offset',
#  'Stage vector Y',
#  'Argon Condenser is',
#  'Frames to average',
#  'Dual Mag Gain X',
#  'Stage goto T',
#  'Chamber',
#  'EHT Cal@10KV',
#  'Pa 8',
#  'V 5',
#  'Stage Delta M',
#  'Print No.',
#  'ESD Excitation',
#  'Peltier Target',
#  'ESB Grid',
#  'Contrast C',
#  'Mill Item Total Time',
#  'Stigmation Y',
#  'Pb 4',
#  'Calibrate Mag Lower X',
#  'Da 3',
#  'System Vacuum',
#  'Argon Energy',
#  'Scan Y cal.',
#  'Stage low T',
#  'Mag Gain Cal Y',
#  'H 9',
#  'Stage low R',
#  'Aperture Align Y',
#  'FIB SEM Angle',
#  'EPD High Limit',
#  'C2 Cal',
#  'Slice Height',
#  'Zoom Posn X',
#  'Pa 2',
#  'Tilt Align Y',
#  'FIB Min. Autoheat Current',
#  'Chamber Pressure Detailed',
#  'Stage high X',
#  'Collector Bias',
#  'Focus scan max',
#  'Test Val',
#  'H 3',
#  'Db 2',
#  'FIB Aper.Align Y',
#  'FIB Fil V target',
#  'Drift Min Conf',
#  'Beam Shift Align X',
#  'Fisheye Orthog',
#  'Gun Shift X',
#  'Contrast B',
#  'Focus Rotation comp.',
#  'Shift Amp Upper Gain Y',
#  'FIB Track WD Delta',
#  'Stage field size X',
#  'Argon V Int',
#  'Offset A',
#  'Width',
#  'Mag Shift Cal Y',
#  'Pirani Pressure',
#  'Liner Tube',
#  'Aperture Align Y',
#  'Stage goto M',
#  'Pb 7',
#  'V 10',
#  'Db 3',
#  'Flood Gun Serial Number',
#  'FIB Stig X',
#  'Stage at M',
#  'Stage at Z',
#  'Stage at Y',
#  'Fil I',
#  'Stage at X',
#  'EHT',
#  'Stage at T',
#  'Sample at Y',
#  'Stage at R',
#  'Sample at X',
#  'Time',
#  'Date',
#  'Version',
#  'User Text',
#  'File Name',
#  'Images',
#  'User Name',
#  'Sample ID',
#  'Serial No.',
#  'Operator']

# %%
PIL_keys = list(PIL_md)

PIL_keys
# Out:
# ['Vent inhibit',
#  'OptiBeam Mode',
#  'VP Aperture',
#  'Input LUT Mode',
#  'BSD Autolevel Mode',
#  'Recipe',
#  'Signal B',
#  'BSD Fast',
#  'Opt.Aperture',
#  'Track Z',
#  'EPSE Electrode',
#  'C3 Rot Corrn.',
#  'Fisheye Mode',
#  'Stage Tilt',
#  'Argon Gun',
#  'Column Isolated',
#  'Mixing',
#  'Flood Gun Mode Target',
#  'STEM Gain',
#  'High Current',
#  'Dwell Time',
#  'SmartImage Noise Reduction',
#  'Right Frozen',
#  'Flood Gun Blanked',
#  'Fast Mode',
#  'Compuc. Mode',
#  'Anode Aperture Changer',
#  'GIS Shutdown State',
#  'FIB Column',
#  'Stage Tilted',
#  'FIB Suppressor is',
#  'VPSE detector',
#  'Crosshairs',
#  'Double Deflection State',
#  'WDX Gate Valve posn',
#  'HE-SE2 Fitted',
#  'EP Gas',
#  'Condenser Normal',
#  'Invert B',
#  'BSD Gain',
#  'FIB Gun Valve',
#  'Aperture',
#  'Electron Counting',
#  'Saturate at',
#  'Stage Angle corrn.',
#  'Store resolution',
#  'Field Mode',
#  'CoolStage Type',
#  'Best Aperture',
#  'Flood Gun Actual Mode',
#  'STEM Auto',
#  'Stage Initialised',
#  'GIS Channel with CC',
#  'Display',
#  'Flood Gun Fitted',
#  'BSD Mode',
#  'FIB Mode',
#  'Nano Tips',
#  'BSD Invert',
#  'MGS Evacuation State',
#  'Use End Point Detection',
#  'Mains Sync',
#  'FIB preparation for pneumatic',
#  'Image',
#  'Filament Type',
#  'Sample Holder',
#  'FIB Scan',
#  'Beam Blanked',
#  'CC Type',
#  'BSD',
#  'Image saved',
#  'Mag Range',
#  'User Align',
#  'Zone',
#  'Filament blown',
#  'Humidity Valve',
#  'Peltier Photo',
#  'Control',
#  'Invert A',
#  'Remoting Target',
#  'Stage Is',
#  'FIB Present',
#  'Peltier Type',
#  'Signal A Z0',
#  'Freeze on',
#  'FIB Blanked',
#  'Beam deceleration',
#  'EPSE Gain',
#  'End Detection',
#  'Vac comms fail',
#  'BSD Auto Range',
#  'Pneumatic Device in use',
#  'FIB Wide View',
#  'Anode Spacer',
#  'Reference Mag',
#  'Stage Bias',
#  'User Calibration',
#  'Safe STEM Valid',
#  'Q5',
#  'SCD Gain',
#  'All Zones',
#  'Signal A',
#  'EHT tripped',
#  'Flood State',
#  'Extractor Trip',
#  'BSD Fast Scan',
#  'InlensDuo Mode',
#  'Auto BC',
#  'Flood Gun Remoting Actual',
#  'Signal A Z1',
#  'Variable stage bias fitted',
#  'EPSE Auto Range',
#  'Stage comms fail',
#  'OptiProbe',
#  'C.L.S.Valve',
#  'New Filament',
#  'Image Detect',
#  'Custom Holder',
#  'Zoom',
#  'SCD Auto Range',
#  'Ext.Scan Control',
#  'Detector',
#  'EHT spurious reset',
#  'STEM Q4',
#  'Extractor Target State',
#  'Jazz Gain',
#  'Monitor',
#  'Freeze',
#  'FIB Extractor Conflict',
#  'Beam deceleration carousel',
#  'EPSE Bandwidth',
#  'Stage bias low voltage',
#  'Stig Balance',
#  'Frame Grabber',
#  'VPSE-G3 Fitted',
#  'Q1',
#  'FIB Lock Mags',
#  'Freeze Blanks',
#  'Windowing',
#  'Partial Vent on Standby',
#  'SCD Bandwidth',
#  'Calibration',
#  'STEM Q1',
#  'EHT Vac ready',
#  'STEM Q5',
#  'Flood Gun Extractor Actual State',
#  'full service bakeout',
#  'Water OK',
#  'Low Mag',
#  'Venting inhibited',
#  'FIB Probe',
#  'Display LUT mode',
#  'OptiBeam Is',
#  'ScanGen Type',
#  'Final Lens',
#  'EHT Comms Fail',
#  'Scan Gen',
#  'Num. Regions',
#  'FIB Error',
#  'GIS Heating Status Channel 1',
#  'BSD Bandwidth',
#  'Q2',
#  'Dyn.Focus',
#  'Supervisor',
#  'Colour Mode',
#  'Tilt Corrn.',
#  'Spot',
#  'EP Aperture',
#  'Noise reduction for fast scanspeeds',
#  'SESI Mode',
#  'Fish-Eye Fitted',
#  'STEM Q2',
#  'Pix Size state',
#  'Beam Blanker Mode',
#  'FIB Image Probe',
#  'Argon Mill',
#  'FIB Mag Range',
#  'User Level',
#  'Argon Scan',
#  'Chamber Status',
#  'Column',
#  'Large Beam Shift',
#  'Argon MFC Valve',
#  'Contrast Enhanced',
#  'Q3',
#  'Scan Rot',
#  'Sem drift status',
#  'Line Scan',
#  'Signal A Z2',
#  'SCM range',
#  'Flood Gun Type',
#  'STEM Q3',
#  'Mag State',
#  'Go to HV @ Shutdown',
#  'SCM Status',
#  'SI source-hidden',
#  'OptiBeam conjugate',
#  'Flood Gun Status',
#  'VP Optibeam',
#  'Condenser Reversed',
#  'Zone 0',
#  'FIB Milling Probe',
#  'Scint.',
#  'OptiBeam Res Mode',
#  'Jazz Bandwidth',
#  'IGP Enabled',
#  'WDX Gate valve',
#  'Peltier',
#  'Output Reduction',
#  'Q4',
#  'Aperture No.',
#  'Sem',
#  'Scan Orthog',
#  'Channels',
#  'Dual Monitor',
#  'Signal A Z3',
#  'C3 Rotn Sign',
#  'STEM Fast',
#  'Output dev',
#  'User',
#  'FIB Tracking WD',
#  'Flood Gun Interlock',
#  'Low KV Lens',
#  'Zone 1',
#  'CC Status',
#  'FIB Gun State',
#  'Argon Gun is',
#  'Output To',
#  'Column Chamber valve',
#  'Column pumping',
#  'Scan Speed',
#  'All Frozen',
#  'Operating Mode',
#  'GIS Channel',
#  'FIB Imaging',
#  'C3 Reversal',
#  'Vacuum Mode',
#  'Column Mode',
#  'STEM Seg. Mode',
#  'Cal Mode',
#  'Beam State',
#  'Noise Reduction',
#  'OptiBeam',
#  'Vac Status',
#  'Flood Gun Emission target',
#  'FIB Shift Correction Y',
#  'Mag',
#  'Line Time',
#  'FIB Mag fine gain Y',
#  'Spot at Y',
#  'Orthogonality Lower',
#  'Aa 4',
#  'Stage vector X',
#  'Argon Condenser',
#  'Min Mag',
#  'Stage goto R',
#  'VP Target',
#  'EHT Cal@0.1KV',
#  'Pa 7',
#  'V 4',
#  'Stage Delta R',
#  'File No',
#  'ESD Lower Y',
#  'Free WD',
#  'Brightness D',
#  'Field Mode Quadriture',
#  'Tilt Angle',
#  'Mill List Elapsed Time',
#  'Stigmation X',
#  'Pb 3',
#  'Calibrate Mag Upper Y',
#  'Da 2',
#  'Reduced Raster Width',
#  'VPSE G3 Bias',
#  'Stage low Z',
#  'Argon Magnification',
#  'Argon Shift Ratio Y',
#  'Scan X cal.',
#  'Stage high T',
#  'Profile Top',
#  'Mag Gain Cal X',
#  'H 8',
#  'Spacer Thickness',
#  'Stage high R',
#  'FIB Condenser',
#  'Flood Gun Filament Target',
#  'Aperture Align X',
#  'SEM Level @',
#  'Vac Ready @',
#  'C1 Rem',
#  'Slice Width',
#  'Beam Shift Y',
#  'Pa 1',
#  'Tilt Align X',
#  'Stage X+M Rotation',
#  'SmartImage Topography',
#  'Stage at field Y',
#  'Argon Column Angle',
#  'Test No.',
#  'H 2',
#  'Db 1',
#  'Opt. Semi Angle',
#  'FIB Aper.Align X',
#  'FIB Fil I Target',
#  'Drift Max.Pix.Error',
#  'InlensDuo Grid is',
#  'Fisheye Angle',
#  'Contrast A',
#  'Dual Mag Offset Y',
#  'Mag scaling decel',
#  'Shift Amp Upper Gain X',
#  'Holder Length',
#  'Stage fields Y',
#  'FIB Source Lifetime',
#  'Argon Gas Flow is',
#  'Gain A',
#  'Conjugate posn.',
#  'Mag Shift Cal X',
#  'Back Grid',
#  'Suppressor V',
#  'Pb 6',
#  'V 9',
#  'Profile 2 X2',
#  'FIB Mag',
#  'Flood Gun Emission Actual',
#  'FIB Shift Correction X',
#  'I Probe',
#  'FCF Tilt Angle',
#  'FIB Mag fine gain X',
#  'Stage X+M Angle',
#  'Spot at X',
#  'Orthogonality Upper',
#  'Aa 3',
#  'Stage goto Z',
#  'Argon Discharge I is',
#  'Spot Size',
#  'Pa 6',
#  'V 3',
#  'Stage Delta T',
#  'Specimen Height',
#  'ESD Lower X',
#  'FIB Emission I',
#  'FIB Stig Y Centre Y',
#  'Brightness C',
#  'Field Mode Orthog',
#  'Tilt Axis',
#  'Mill List Total Time',
#  'Aperture Posn Y',
#  'Pb 2',
#  'Calibrate Mag Upper X',
#  'Da 1',
#  'EPSE Bias',
#  'Profile width',
#  'Stage low Y',
#  'Argon Beam Shift Y',
#  'Argon Shift Ratio X',
#  'Xtalk21',
#  'Min Extractor V',
#  'H 7',
#  'Stage Centre Y',
#  'FIB Scan Size',
#  'Stig. Cal Y',
#  'FIB Extractor',
#  'Flood Gun Energy Actual',
#  'FIB Stig X Centre Y',
#  'Piezo Goto Y',
#  'FIB Tilt Comp',
#  'C1 Cal',
#  'Slice Y',
#  'Beam Shift X',
#  'Red.Raster Height',
#  'Calibrate Mag Base',
#  'FIB Nudge Step',
#  'Piezo Exchange Y',
#  'Stage at field X',
#  'Argon Acc I is',
#  'Argon Mill Progress',
#  'Area Fraction',
#  'Nominal Fil I',
#  'Gun at Y',
#  'Stage Vector M',
#  'H 1',
#  'Semi Angle',
#  'FIB Scan Rot',
#  'FIB Fil Voltage',
#  'Stage Angle',
#  'InlensDuo Grid',
#  'Fil I Target',
#  'Brightness B',
#  'Dual Mag Offset X',
#  'Shift Amp Lower Offset Y',
#  'Holder Width',
#  'SmartImage Sharpening',
#  'Stage fields X',
#  'FIB Probe Current Actual',
#  'Argon Gas Flow',
#  'Gamma',
#  'Front Grid',
#  'Extractor V',
#  'Gun Align Y',
#  'Max Extractor V',
#  'Pb 5',
#  'V 8',
#  'Profile 2 X1',
#  'FIB Objective',
#  'Flood Gun Extractor Voltage',
#  'Piezo at Y',
#  'Emission Zoom',
#  'Zoom factor',
#  'FIB Working Distance',
#  'Line To Frame Lower',
#  'Aa 2',
#  'Stage goto Y',
#  'Argon Discharge is',
#  'Mix Signal',
#  'CC Pressure',
#  'N',
#  'Pa 5',
#  'V 2',
#  'Stage Delta Z',
#  'ESD Upper Y',
#  'FIB Abs Beam Shift Y',
#  'FIB Suppressor Target',
#  'FIB Stig Y Centre X',
#  'Purge Min',
#  'FIB Column Pressure',
#  'Field Mode Angle',
#  'C3 Rem',
#  'FIB Pixel Size',
#  'Aperture Posn X',
#  'Pb 1',
#  'C3 saved for beam decel',
#  'ESB Grid is',
#  'EHT set maximum',
#  'Stage low X',
#  'Argon Beam Shift X',
#  'Argon XY Ratio',
#  'Frame Ampl Cal.',
#  'Xtalk12',
#  'Liner Target',
#  'H 6',
#  'Stage Centre X',
#  'Stig. Cal X',
#  'FIB Extr.Target',
#  'Flood Gun Energy Target',
#  'FIB Stig X Centre X',
#  'Piezo Goto X',
#  'C2 Lens I',
#  'Mag Comp. Offset',
#  'Slice X',
#  'Gun Tilt Y',
#  'Red.Raster Width',
#  'Scan Rotation Offset Lower',
#  'Piezo Exchange X',
#  'Stage goto field Y',
#  'Argon Extractor is',
#  'Auto C Target',
#  'Offset B',
#  'Align 1 Y',
#  'Beam Offset Y',
#  'White Threshold',
#  'Gun at X',
#  'EO Temp Limit',
#  'Spot X Cal',
#  'FIB Beam Shift Y',
#  'FIB Fil Current',
#  'Scan Orth corrn',
#  'EHT Target',
#  'Mag Cal Actual Height',
#  'Brightness A',
#  'Decl cal 2',
#  'Shift Amp Lower Offset X',
#  'Holder Diameter',
#  'SmartImage Threshold',
#  'Stage scan angle',
#  'FIB Objective Actual',
#  'Argon Objective is',
#  'Line int. count',
#  'Filament Age',
#  'Dual Mag Gain Y',
#  'Stage vector T',
#  'Peltier Temp',
#  'Gun Align X',
#  'EHT Cal@30KV',
#  'Pa 10',
#  'V 7',
#  'Profile 1 X2',
#  'Stage bias Low Volts',
#  'VP LaB6 Limit',
#  'FIB EHT',
#  'Humidity Target',
#  'Piezo at X',
#  'Line To Frame Upper',
#  'Aa 1',
#  'Reduced Raster Y',
#  'Laser Illumination',
#  'Stage goto X',
#  'Gun Vacuum',
#  'Argon Discharge',
#  'Signal',
#  'Line Avg.Count',
#  'Beam Time',
#  'Cursor Height',
#  'Profile Width 2',
#  'V 1',
#  'Stage Delta Y',
#  'Probe Cal Factor',
#  'ESD Upper X',
#  'FIB Abs Beam Shift X',
#  'FIB Drift Y',
#  'Purge Max',
#  'FIB Heating Limit',
#  'C3 Cal',
#  'Line Counter',
#  'Aperture Size',
#  'Pa 4',
#  'wd saved for beam decel',
#  'Liner Cal @ 10KV',
#  'Beam Current',
#  'Stage high Z',
#  'Convertor Voltage',
#  'Argon Mag Factor',
#  'Mag Z1',
#  'Suppressor V Target',
#  'H 5',
#  'Compu. Height',
#  'FIB Aperture Y Actual',
#  'FIB Emission Target',
#  'C1 Lens I',
#  'Mag Comp. Amplitude',
#  'Slice Index',
#  'Gun Tilt X',
#  'Red.Raster Posn Y',
#  'Shift Amp Lower Gain Y',
#  'Holder Height',
#  'Specimen Diameter',
#  'Stage goto field X',
#  'Argon Extractor',
#  'Auto B Target',
#  'Gain B',
#  'Align 1 X',
#  'Beam Offset X',
#  'Black Threshold',
#  'Nominal extractor V',
#  'Aperture at Y',
#  'Stage high M',
#  'EO Temp',
#  'User Max EHT',
#  'CCD Illum.',
#  'FIB Beam Shift X',
#  'Scan Rotation',
#  'FIB Focus',
#  'Fil I (Usermax)',
#  'Mag Cal Actual Width',
#  'Defect ID',
#  'Decl cal 1',
#  'Shift Amp Upper Offset Y',
#  'SmartImage Contrast',
#  'Stage vector Z',
#  'Argon Objective',
#  'Frames to Int.',
#  'Focus',
#  'Stage vector R',
#  'EHT Cal@24KV',
#  'Pa 9',
#  'V 6',
#  'Profile 1 X1',
#  'HRRU No.',
#  'FIB EHT Target',
#  'Humidity',
#  'ESB Grid Max',
#  'Contrast D',
#  'Mill Item Elapsed Time',
#  'Beam deceleration Volts',
#  'Calibrate Mag Lower Y',
#  'Da 4',
#  'FIB Condenser actual',
#  'Argon Energy is',
#  'Specimen I',
#  'Photo No.',
#  'Field Overlap',
#  'Spot signal',
#  'Cursor Width',
#  'Profile Width 1',
#  'H 10',
#  'Stage Delta X',
#  'Compu. Tilt Error',
#  'FIB Drift X',
#  'Purge cycles',
#  'C3 Lens I',
#  'EPD Low Limit',
#  'C2 Rem',
#  'Slice Angle',
#  'Zoom Posn Y',
#  'Pa 3',
#  'Clip Limit',
#  'Liner cal @ 100V',
#  'Pixel Size',
#  'Stage high Y',
#  'Collector Voltage',
#  'Argon Pixel Size',
#  'Mag Z0',
#  'Focus scan min',
#  'Extractor V Target',
#  'H 4',
#  'Image Pixel Size',
#  'FIB Aperture X Actual',
#  'FIB Suppressor',
#  'Drift Max Tries',
#  'Beam Shift Align Y',
#  'Brightness',
#  'Fisheye quadriture',
#  'Gun Shift Y',
#  'Red.Raster Posn X',
#  'Shift Amp Lower Gain X',
#  'Stage field size Y',
#  'Argon V Int is',
#  'Contrast',
#  'Height',
#  'EHT Set minimum',
#  'Ext I Monitor',
#  'Aperture at X',
#  'Stage low M',
#  'FCF Setting',
#  'Db 4',
#  'FIB Stig Y',
#  'Frame Counter',
#  'Flood Gun Filament Actual',
#  'EP Target',
#  'WD',
#  'HSync delay',
#  'Cycle Time',
#  'FIB Gun Pressure',
#  'Shift Amp Upper Offset X',
#  'Compu. Tilt Offset',
#  'Stage vector Y',
#  'Argon Condenser is',
#  'Frames to average',
#  'Dual Mag Gain X',
#  'Stage goto T',
#  'Chamber',
#  'EHT Cal@10KV',
#  'Pa 8',
#  'V 5',
#  'Stage Delta M',
#  'Print No.',
#  'ESD Excitation',
#  'Peltier Target',
#  'ESB Grid',
#  'Contrast C',
#  'Mill Item Total Time',
#  'Stigmation Y',
#  'Pb 4',
#  'Calibrate Mag Lower X',
#  'Da 3',
#  'System Vacuum',
#  'Argon Energy',
#  'Scan Y cal.',
#  'Stage low T',
#  'Mag Gain Cal Y',
#  'H 9',
#  'Stage low R',
#  'Aperture Align Y',
#  'FIB SEM Angle',
#  'EPD High Limit',
#  'C2 Cal',
#  'Slice Height',
#  'Zoom Posn X',
#  'Pa 2',
#  'Tilt Align Y',
#  'FIB Min. Autoheat Current',
#  'Chamber Pressure Detailed',
#  'Stage high X',
#  'Collector Bias',
#  'Focus scan max',
#  'Test Val',
#  'H 3',
#  'Db 2',
#  'FIB Aper.Align Y',
#  'FIB Fil V target',
#  'Drift Min Conf',
#  'Beam Shift Align X',
#  'Fisheye Orthog',
#  'Gun Shift X',
#  'Contrast B',
#  'Focus Rotation comp.',
#  'Shift Amp Upper Gain Y',
#  'FIB Track WD Delta',
#  'Stage field size X',
#  'Argon V Int',
#  'Offset A',
#  'Width',
#  'Mag Shift Cal Y',
#  'Pirani Pressure',
#  'Liner Tube',
#  'Stage goto M',
#  'Pb 7',
#  'V 10',
#  'Db 3',
#  'Flood Gun Serial Number',
#  'FIB Stig X',
#  'Stage at M',
#  'Stage at Z',
#  'Stage at Y',
#  'Fil I',
#  'Stage at X',
#  'EHT',
#  'Stage at T',
#  'Sample at Y',
#  'Stage at R',
#  'Sample at X',
#  'Time',
#  'Date',
#  'Version',
#  'User Text',
#  'File Name',
#  'Images',
#  'User Name',
#  'Sample ID',
#  'Serial No.',
#  'Operator']

# %%
# Things in PIL but not in HS
for k in PIL_keys:
    if k not in hyperspy_keys:
        print(f"key {k} in PIL metadata with value {PIL_md[k]}")
# Out:
# key N in PIL metadata with value 1

# %%
# Things in HS but not in PIL
for k in hyperspy_keys:
    if k not in PIL_keys:
        print(k)

# %%
PIL_md
# Out:
# {'Vent inhibit': ('Beam', 'Present'),
#  'OptiBeam Mode': 'Resolution',
#  'VP Aperture': 'No',
#  'Input LUT Mode': 'Transparent',
#  'BSD Autolevel Mode': 'Normal',
#  'Recipe': 'Idle',
#  'Signal B': (),
#  'BSD Fast': 'No',
#  'Opt.Aperture': '2',
#  'Track Z': 'Off',
#  'EPSE Electrode': 'Ring',
#  'C3 Rot Corrn.': 'On',
#  'Fisheye Mode': 'Off',
#  'Stage Tilt': ('in', 'X'),
#  'Argon Gun': 'Absent',
#  'Column Isolated': 'No',
#  'Mixing': 'Off',
#  'Flood Gun Mode Target': ('Low', 'Energy', 'Mode'),
#  'STEM Gain': 'Low',
#  'High Current': 'Off',
#  'Dwell Time': ('100', 'ns'),
#  'SmartImage Noise Reduction': 'Off',
#  'Right Frozen': 'Yes',
#  'Flood Gun Blanked': 'No',
#  'Fast Mode': 'Off',
#  'Compuc. Mode': 'Off',
#  'Anode Aperture Changer': 'Absent',
#  'GIS Shutdown State': 'Normal',
#  'FIB Column': 'None',
#  'Stage Tilted': 'No',
#  'FIB Suppressor is': 'Absent',
#  'VPSE detector': 'Absent',
#  'Crosshairs': 'Off',
#  'Double Deflection State': 'Off',
#  'WDX Gate Valve posn': 'OK',
#  'HE-SE2 Fitted': 'No',
#  'EP Gas': 'Air',
#  'Condenser Normal': 'Normal',
#  'Invert B': 'Off',
#  'BSD Gain': 'High',
#  'FIB Gun Valve': 'Closed',
#  'Aperture': 'Clean',
#  'Electron Counting': 'Off',
#  'Saturate at': ('Second', 'peak'),
#  'Stage Angle corrn.': 'On',
#  'Store resolution': ('1024', '*', '768'),
#  'Field Mode': 'Off',
#  'CoolStage Type': 'Cold',
#  'Best Aperture': 'Yes',
#  'Flood Gun Actual Mode': ('Low', 'Energy', 'Mode'),
#  'STEM Auto': 'Off',
#  'Stage Initialised': 'Yes',
#  'GIS Channel with CC': 'None',
#  'Display': '0',
#  'Flood Gun Fitted': 'No',
#  'BSD Mode': 'Topo',
#  'FIB Mode': 'Imaging',
#  'Nano Tips': 'Absent',
#  'BSD Invert': 'No',
#  'MGS Evacuation State': 'Off',
#  'Use End Point Detection': 'No',
#  'Mains Sync': ('Single', 'Edge'),
#  'FIB preparation for pneumatic': ('FIB', 'ready', 'for', 'system', 'vent'),
#  'Image': 'Frozen',
#  'Filament Type': ('FE', 'FEI'),
#  'Sample Holder': (),
#  'FIB Scan': 'Continuous',
#  'Beam Blanked': 'Yes',
#  'CC Type': 'None',
#  'BSD': 'Absent',
#  'Image saved': 'Yes',
#  'Mag Range': '3',
#  'User Align': 'On',
#  'Zone': '0',
#  'Filament blown': 'No',
#  'Humidity Valve': 'Closed',
#  'Peltier Photo': 'Off',
#  'Control': ('Signal', 'A'),
#  'Invert A': 'Off',
#  'Remoting Target': ('Flood', 'Gun', 'Normal'),
#  'Stage Is': 'Idle',
#  'FIB Present': 'No',
#  'Peltier Type': 'Deben',
#  'Signal A Z0': 'InLens',
#  'Freeze on': ('End', 'Frame'),
#  'FIB Blanked': 'No',
#  'Beam deceleration': 'Off',
#  'EPSE Gain': 'Low',
#  'End Detection': 'Off',
#  'Vac comms fail': 'No',
#  'BSD Auto Range': 'On',
#  'Pneumatic Device in use': 'None',
#  'FIB Wide View': 'Off',
#  'Anode Spacer': ('High', 'KV'),
#  'Reference Mag': ('Out', 'Dev.'),
#  'Stage Bias': 'Off',
#  'User Calibration': 'Off',
#  'Safe STEM Valid': 'No',
#  'Q5': 'Off',
#  'SCD Gain': 'Low',
#  'All Zones': 'Off',
#  'Signal A': 'InLens',
#  'EHT tripped': 'No',
#  'Flood State': 'Idle',
#  'Extractor Trip': 'No',
#  'BSD Fast Scan': 'Off',
#  'InlensDuo Mode': 'SE',
#  'Auto BC': 'Off',
#  'Flood Gun Remoting Actual': ('Flood', 'Gun', 'Normal'),
#  'Signal A Z1': 'InLens',
#  'Variable stage bias fitted': 'No',
#  'EPSE Auto Range': 'Off',
#  'Stage comms fail': 'No',
#  'OptiProbe': 'Off',
#  'C.L.S.Valve': 'Closed',
#  'New Filament': 'No',
#  'Image Detect': 'Black',
#  'Custom Holder': 'No',
#  'Zoom': 'Off',
#  'SCD Auto Range': 'Off',
#  'Ext.Scan Control': 'Off',
#  'Detector': 'InLens',
#  'EHT spurious reset': 'No',
#  'STEM Q4': 'Off',
#  'Extractor Target State': 'Off',
#  'Jazz Gain': 'Low',
#  'Monitor': ('19/21', 'inch'),
#  'Freeze': 'Idle',
#  'FIB Extractor Conflict': 'No',
#  'Beam deceleration carousel': 'No',
#  'EPSE Bandwidth': 'DC',
#  'Stage bias low voltage': 'Off',
#  'Stig Balance': 'Off',
#  'Frame Grabber': ('Matrix', 'Titan'),
#  'VPSE-G3 Fitted': 'Absent',
#  'Q1': 'Off',
#  'FIB Lock Mags': 'No',
#  'Freeze Blanks': 'Yes',
#  'Windowing': 'Off',
#  'Partial Vent on Standby': 'No',
#  'SCD Bandwidth': 'DC',
#  'Calibration': 'Disabled',
#  'STEM Q1': 'Off',
#  'EHT Vac ready': 'Yes',
#  'STEM Q5': 'Off',
#  'Flood Gun Extractor Actual State': 'Off',
#  'full service bakeout': 'No',
#  'Water OK': 'Yes',
#  'Low Mag': 'Off',
#  'Venting inhibited': 'Yes',
#  'FIB Probe': 'Undefined',
#  'Display LUT mode': 'Normal',
#  'OptiBeam Is': 'Off',
#  'ScanGen Type': 'L-REM',
#  'Final Lens': ('1500:', 'Gemini'),
#  'EHT Comms Fail': 'No',
#  'Scan Gen': 'Present',
#  'Num. Regions': '0',
#  'FIB Error': 'None',
#  'GIS Heating Status Channel 1': ('GIS', 'Not', 'Heating'),
#  'BSD Bandwidth': 'DC',
#  'Q2': 'Off',
#  'Dyn.Focus': 'Off',
#  'Supervisor': 'Disabled',
#  'Colour Mode': 'Off',
#  'Tilt Corrn.': 'Off',
#  'Spot': 'Off',
#  'EP Aperture': ('None', 'fitted'),
#  'Noise reduction for fast scanspeeds': 'No',
#  'SESI Mode': 'SE',
#  'Fish-Eye Fitted': 'Yes',
#  'STEM Q2': 'Off',
#  'Pix Size state': 'calibrated',
#  'Beam Blanker Mode': 'Blanked',
#  'FIB Image Probe': 'Undefined',
#  'Argon Mill': 'Off',
#  'FIB Mag Range': '0',
#  'User Level': 'Expert',
#  'Argon Scan': 'Off',
#  'Chamber Status': ('Power', 'Up'),
#  'Column': '1500',
#  'Large Beam Shift': 'Off',
#  'Argon MFC Valve': 'Closed',
#  'Contrast Enhanced': 'No',
#  'Q3': 'Off',
#  'Scan Rot': 'Off',
#  'Sem drift status': ('Not', 'Available'),
#  'Line Scan': 'Off',
#  'Signal A Z2': 'InLens',
#  'SCM range': ('3->10', 'pA'),
#  'Flood Gun Type': ('Flood', 'Gun', 'Unknown', 'Type'),
#  'STEM Q3': 'Off',
#  'Mag State': 'calibrated',
#  'Go to HV @ Shutdown': 'No',
#  'SCM Status': 'Off',
#  'SI source-hidden': '0',
#  'OptiBeam conjugate': 'Off',
#  'Flood Gun Status': 'Off',
#  'VP Optibeam': 'Off',
#  'Condenser Reversed': 'No',
#  'Zone 0': 'Frozen',
#  'FIB Milling Probe': 'Undefined',
#  'Scint.': 'On',
#  'OptiBeam Res Mode': 'manual',
#  'Jazz Bandwidth': 'Low',
#  'IGP Enabled': 'Yes',
#  'WDX Gate valve': 'Closed',
#  'Peltier': 'Off',
#  'Output Reduction': '1',
#  'Q4': 'Off',
#  'Aperture No.': '1',
#  'Sem': ('Supra', '40'),
#  'Scan Orthog': 'On',
#  'Channels': '1',
#  'Dual Monitor': 'Off',
#  'Signal A Z3': 'InLens',
#  'C3 Rotn Sign': '+',
#  'STEM Fast': 'No',
#  'Output dev': ('19/21', 'inch', 'display'),
#  'User': 'Idle',
#  'FIB Tracking WD': 'Off',
#  'Flood Gun Interlock': 'No',
#  'Low KV Lens': 'Absent',
#  'Zone 1': 'Frozen',
#  'CC Status': 'Off',
#  'FIB Gun State': 'Off',
#  'Argon Gun is': 'Off',
#  'Output To': 'Display/File',
#  'Column Chamber valve': 'Open',
#  'Column pumping': 'Ready',
#  'Scan Speed': '9',
#  'All Frozen': 'Yes',
#  'Operating Mode': 'Normal',
#  'GIS Channel': 'None',
#  'FIB Imaging': 'SEM',
#  'C3 Reversal': 'Normal',
#  'Vacuum Mode': ('High', 'Vacuum'),
#  'Column Mode': ('High', 'Resolution'),
#  'STEM Seg. Mode': 'Off',
#  'Cal Mode': 'Off',
#  'Beam State': ('Beam', 'On'),
#  'Noise Reduction': ('Pixel', 'Avg.'),
#  'OptiBeam': 'Off',
#  'Vac Status': 'Ready',
#  'Flood Gun Emission target': ('0.0', 'µA'),
#  'FIB Shift Correction Y': ('0.00', 'nm'),
#  'Mag': ('399.85', 'K', 'X'),
#  'Line Time': ('26.32', 'ms'),
#  'FIB Mag fine gain Y': '0.0000',
#  'Spot at Y': '192',
#  'Orthogonality Lower': ('0.0', '°'),
#  'Aa 4': ('0.000', 'kV'),
#  'Stage vector X': ('0.0', '%'),
#  'Argon Condenser': ('0', 'V'),
#  'Min Mag': ('90', 'X'),
#  'Stage goto R': ('4.2', '°'),
#  'VP Target': ('10', 'Pa'),
#  'EHT Cal@0.1KV': ('108', 'V'),
#  'Pa 7': ('0.00', 'nm'),
#  'V 4': ('0.00', 'nm'),
#  'Stage Delta R': ('0.0', '°'),
#  'File No': '1891',
#  'ESD Lower Y': ('0.0', '%'),
#  'Free WD': ('4.0', 'mm'),
#  'Brightness D': ('29.9', '%'),
#  'Field Mode Quadriture': '-1',
#  'Tilt Angle': ('0.0', '°'),
#  'Mill List Elapsed Time': ('0', 'ms'),
#  'Stigmation X': ('-1.8', '%'),
#  'Pb 3': ('7.6', '°'),
#  'Calibrate Mag Upper Y': '0.0000',
#  'Da 2': ('0.00', 'nm'),
#  'Reduced Raster Width': '512',
#  'VPSE G3 Bias': ('60.0', '%'),
#  'Stage low Z': ('0.000', 'mm'),
#  'Argon Magnification': ('0', 'X'),
#  'Argon Shift Ratio Y': '0.0000',
#  'Scan X cal.': '0',
#  'Stage high T': ('0.0', '°'),
#  'Profile Top': '300',
#  'Mag Gain Cal X': '1000.00',
#  'H 8': ('0.00', 'nm'),
#  'Spacer Thickness': ('0.000', 'mm'),
#  'Stage high R': ('380.0', '°'),
#  'FIB Condenser': ('0', 'V'),
#  'Flood Gun Filament Target': ('0', 'µA'),
#  'Aperture Align X': ('-10.4', '%'),
#  'SEM Level @': ('0.0', '°'),
#  'Vac Ready @': ('1.00e-004', 'mbar'),
#  'C1 Rem': '0.0105',
#  'Slice Width': ('0.00', 'nm'),
#  'Beam Shift Y': ('11.6', '%'),
#  'Pa 1': ('20.43', 'µm'),
#  'Tilt Align X': ('0.0', '%'),
#  'Stage X+M Rotation': ('0.0', '°'),
#  'SmartImage Topography': ('0.0', '%'),
#  'Stage at field Y': '1',
#  'Argon Column Angle': ('0.0', '°'),
#  'Test No.': '0',
#  'H 2': ('0.00', 'nm'),
#  'Db 1': ('0.', 'nm²'),
#  'Opt. Semi Angle': ('0.00', 'µrad'),
#  'FIB Aper.Align X': '0',
#  'FIB Fil I Target': ('0', 'µA'),
#  'Drift Max.Pix.Error': '1',
#  'InlensDuo Grid is': ('0', 'V'),
#  'Fisheye Angle': ('0.0', '°'),
#  'Contrast A': ('41.5', '%'),
#  'Dual Mag Offset Y': '3.000',
#  'Mag scaling decel': '1.0000',
#  'Shift Amp Upper Gain X': '0.0000',
#  'Holder Length': ('0.000', 'mm'),
#  'Stage fields Y': '1',
#  'FIB Source Lifetime': ('0.00', 'µAh'),
#  'Argon Gas Flow is': ('0.0', '%'),
#  'Gain A': ('100.0', '%'),
#  'Conjugate posn.': ('-164.00', 'mm'),
#  'Mag Shift Cal X': '0.0000',
#  'Back Grid': ('0', 'V'),
#  'Suppressor V': ('300', 'V'),
#  'Pb 6': ('0.0', '°'),
#  'V 9': ('0.00', 'nm'),
#  'Profile 2 X2': '0',
#  'FIB Mag': ('0', 'X'),
#  'Flood Gun Emission Actual': ('0.0', 'µA'),
#  'FIB Shift Correction X': ('0.00', 'nm'),
#  'I Probe': ('200.0', 'nA'),
#  'FCF Tilt Angle': ('0.0', '°'),
#  'FIB Mag fine gain X': '0.0000',
#  'Stage X+M Angle': ('8.0', '°'),
#  'Spot at X': '256',
#  'Orthogonality Upper': ('0.0', '°'),
#  'Aa 3': ('0.000', 'kV'),
#  'Stage goto Z': ('49.500', 'mm'),
#  'Argon Discharge I is': ('0.0', 'µA'),
#  'Spot Size': '1',
#  'Pa 6': ('0.00', 'nm'),
#  'V 3': ('0.00', 'nm'),
#  'Stage Delta T': ('0.0', '°'),
#  'Specimen Height': ('1', 'mm'),
#  'ESD Lower X': ('0.0', '%'),
#  'FIB Emission I': ('0.0', 'µA'),
#  'FIB Stig Y Centre Y': '0.0000',
#  'Brightness C': ('29.9', '%'),
#  'Field Mode Orthog': ('-1.0', '°'),
#  'Tilt Axis': ('90.0', '°'),
#  'Mill List Total Time': ('0', 'ms'),
#  'Aperture Posn Y': ('1.000', 'mm'),
#  'Pb 2': ('3.8', '°'),
#  'Calibrate Mag Upper X': '0.0000',
#  'Da 1': ('0.00', 'nm'),
#  'EPSE Bias': ('0.0', '%'),
#  'Profile width': ('0.00', 'nm'),
#  'Stage low Y': ('0.000', 'mm'),
#  'Argon Beam Shift Y': ('0.00', 'nm'),
#  'Argon Shift Ratio X': '0.0000',
#  'Xtalk21': '0.0000',
#  'Min Extractor V': ('3.00', 'kV'),
#  'H 7': ('0.00', 'nm'),
#  'Stage Centre Y': ('65.000', 'mm'),
#  'FIB Scan Size': ('0.00', 'nm'),
#  'Stig. Cal Y': ('0.0', '%'),
#  'FIB Extractor': ('0.000', 'kV'),
#  'Flood Gun Energy Actual': ('0.00', 'V'),
#  'FIB Stig X Centre Y': '0.0000',
#  'Piezo Goto Y': ('0.000', 'µm'),
#  'FIB Tilt Comp': ('0.0', '°'),
#  'C1 Cal': '0.9580',
#  'Slice Y': ('0.00', 'nm'),
#  'Beam Shift X': ('-12.9', '%'),
#  'Red.Raster Height': '151',
#  'Calibrate Mag Base': '50000.00',
#  'FIB Nudge Step': ('0.00', 'nm'),
#  'Piezo Exchange Y': ('0.000', 'µm'),
#  'Stage at field X': '1',
#  'Argon Acc I is': ('0.0', 'µA'),
#  'Argon Mill Progress': ('0.0', '%'),
#  'Area Fraction': ('0.0', '%'),
#  'Nominal Fil I': ('2.250', 'A'),
#  'Gun at Y': ('4.0', '%'),
#  'Stage Vector M': ('0.0', '%'),
#  'H 1': ('0.00', 'nm'),
#  'Semi Angle': ('0.00', 'µrad'),
#  'FIB Scan Rot': ('0.0', '°'),
#  'FIB Fil Voltage': ('0.0', 'V'),
#  'Stage Angle': ('180.0', '°'),
#  'InlensDuo Grid': ('0', 'V'),
#  'Fil I Target': ('2.250', 'A'),
#  'Brightness B': ('29.9', '%'),
#  'Dual Mag Offset X': '0.0000',
#  'Shift Amp Lower Offset Y': '0.0000',
#  'Holder Width': ('0.000', 'mm'),
#  'SmartImage Sharpening': ('0.0', '%'),
#  'Stage fields X': '1',
#  'FIB Probe Current Actual': ('0.0', 'pA'),
#  'Argon Gas Flow': ('0.0', '%'),
#  'Gamma': '1.0000',
#  'Front Grid': ('0', 'V'),
#  'Extractor V': ('5.40', 'kV'),
#  'Gun Align Y': ('0.0', '%'),
#  'Max Extractor V': ('7.00', 'kV'),
#  'Pb 5': ('4.4', '°'),
#  'V 8': ('0.00', 'nm'),
#  'Profile 2 X1': '0',
#  'FIB Objective': ('0', 'V'),
#  'Flood Gun Extractor Voltage': ('0', 'V'),
#  'Piezo at Y': ('0.000', 'µm'),
#  'Emission Zoom': '100',
#  'Zoom factor': '2.000',
#  'FIB Working Distance': ('0.0', 'mm'),
#  'Line To Frame Lower': '0.0000',
#  'Aa 2': ('0.0', '°'),
#  'Stage goto Y': ('50.711', 'mm'),
#  'Argon Discharge is': ('0', 'V'),
#  'Mix Signal': '0.0000',
#  'CC Pressure': ('0.0', '%'),
#  'N': '1',
#  'Pa 5': ('218.2', 'nm'),
#  'V 2': ('0.00', 'nm'),
#  'Stage Delta Z': ('0.000', 'mm'),
#  'ESD Upper Y': ('0.0', '%'),
#  'FIB Abs Beam Shift Y': ('0.00', 'nm'),
#  'FIB Suppressor Target': ('0', 'V'),
#  'FIB Stig Y Centre X': '0.0000',
#  'Purge Min': ('133', 'Pa'),
#  'FIB Column Pressure': ('0.00e+000', 'mbar'),
#  'Field Mode Angle': ('-1.0', '°'),
#  'C3 Rem': '0.0137',
#  'FIB Pixel Size': ('0.0', 'fm'),
#  'Aperture Posn X': ('5.000', 'mm'),
#  'Pb 1': ('0.5', '°'),
#  'C3 saved for beam decel': ('0', 'µA'),
#  'ESB Grid is': ('0', 'V'),
#  'EHT set maximum': ('30.00', 'kV'),
#  'Stage low X': ('0.000', 'mm'),
#  'Argon Beam Shift X': ('0.00', 'nm'),
#  'Argon XY Ratio': '0.0000',
#  'Frame Ampl Cal.': '0',
#  'Xtalk12': '0.0000',
#  'Liner Target': ('8.00', 'kV'),
#  'H 6': ('0.00', 'nm'),
#  'Stage Centre X': ('65.000', 'mm'),
#  'Stig. Cal X': ('0.0', '%'),
#  'FIB Extr.Target': ('0.000', 'kV'),
#  'Flood Gun Energy Target': ('0.00', 'V'),
#  'FIB Stig X Centre X': '0.0000',
#  'Piezo Goto X': ('0.000', 'µm'),
#  'C2 Lens I': ('0', 'µA'),
#  'Mag Comp. Offset': '513',
#  'Slice X': ('0.00', 'nm'),
#  'Gun Tilt Y': ('0.0', '%'),
#  'Red.Raster Width': '160',
#  'Scan Rotation Offset Lower': ('0.0', '°'),
#  'Piezo Exchange X': ('0.000', 'µm'),
#  'Stage goto field Y': '1',
#  'Argon Extractor is': ('0', 'V'),
#  'Auto C Target': ('100.0', '%'),
#  'Offset B': ('0.0', '%'),
#  'Align 1 Y': ('0.0', '%'),
#  'Beam Offset Y': ('1.153', 'µm'),
#  'White Threshold': ('100.0', '%'),
#  'Gun at X': ('-9.5', '%'),
#  'EO Temp Limit': ('35.0', '°C'),
#  'Spot X Cal': '0',
#  'FIB Beam Shift Y': ('0.00', 'nm'),
#  'FIB Fil Current': ('0', 'µA'),
#  'Scan Orth corrn': ('0.8', '°'),
#  'EHT Target': ('5.00', 'kV'),
#  'Mag Cal Actual Height': ('0.00', 'nm'),
#  'Brightness A': ('29.9', '%'),
#  'Decl cal 2': '1.0000',
#  'Shift Amp Lower Offset X': '0.0000',
#  'Holder Diameter': ('50.000', 'mm'),
#  'SmartImage Threshold': ('0.0', '%'),
#  'Stage scan angle': ('0.0', '°'),
#  'FIB Objective Actual': ('0', 'V'),
#  'Argon Objective is': ('0', 'V'),
#  'Line int. count': '1',
#  'Filament Age': ('62717.03', 'Hours'),
#  'Dual Mag Gain Y': '670.00',
#  'Stage vector T': ('0.0', '%'),
#  'Peltier Temp': ('20.0', '°C'),
#  'Gun Align X': ('0.0', '%'),
#  'EHT Cal@30KV': ('30.06', 'kV'),
#  'Pa 10': ('0.00', 'nm'),
#  'V 7': ('0.00', 'nm'),
#  'Profile 1 X2': '59',
#  'Stage bias Low Volts': ('0.0', 'V'),
#  'VP LaB6 Limit': ('274', 'Pa'),
#  'FIB EHT': ('0.000', 'kV'),
#  'Humidity Target': ('0.0', '%'),
#  'Piezo at X': ('0.000', 'µm'),
#  'Line To Frame Upper': '0.0000',
#  'Aa 1': ('0.0', '°'),
#  'Reduced Raster Y': '192',
#  'Laser Illumination': ('0.0', '%'),
#  'Stage goto X': ('51.808', 'mm'),
#  'Gun Vacuum': ('3.61e-010', 'mbar'),
#  'Argon Discharge': ('0', 'V'),
#  'Signal': '1.0000',
#  'Line Avg.Count': '2',
#  'Beam Time': ('4592.74', 'Hours'),
#  'Cursor Height': ('0.00', 'nm'),
#  'Profile Width 2': ('0.00', 'nm'),
#  'V 1': ('0.00', 'nm'),
#  'Stage Delta Y': ('0.000', 'mm'),
#  'Probe Cal Factor': '1.0000',
#  'ESD Upper X': ('0.0', '%'),
#  'FIB Abs Beam Shift X': ('0.00', 'nm'),
#  'FIB Drift Y': ('0.00', 'nm'),
#  'Purge Max': ('1066', 'Pa'),
#  'FIB Heating Limit': ('0', 'µA'),
#  'C3 Cal': '0.9390',
#  'Line Counter': '767',
#  'Aperture Size': ('30.00', 'µm'),
#  'Pa 4': ('239.8', 'nm'),
#  'wd saved for beam decel': ('10.0', 'mm'),
#  'Liner Cal @ 10KV': ('10000', 'V'),
#  'Beam Current': ('80.0', 'µA'),
#  'Stage high Z': ('49.500', 'mm'),
#  'Convertor Voltage': ('0.000', 'kV'),
#  'Argon Mag Factor': ('0.00', 'nm'),
#  'Mag Z1': '1.0000',
#  'Suppressor V Target': ('300', 'V'),
#  'H 5': ('0.00', 'nm'),
#  'Compu. Height': ('0.000', 'mm'),
#  'FIB Aperture Y Actual': '0',
#  'FIB Emission Target': ('0.0', 'µA'),
#  'C1 Lens I': ('0', 'µA'),
#  'Mag Comp. Amplitude': ('37.0', '%'),
#  'Slice Index': '0',
#  'Gun Tilt X': ('0.0', '%'),
#  'Red.Raster Posn Y': '244',
#  'Shift Amp Lower Gain Y': '0.0000',
#  'Holder Height': ('13.700', 'mm'),
#  'Specimen Diameter': ('10', 'mm'),
#  'Stage goto field X': '1',
#  'Argon Extractor': ('0', 'V'),
#  'Auto B Target': ('100.0', '%'),
#  'Gain B': ('100.0', '%'),
#  'Align 1 X': ('0.0', '%'),
#  'Beam Offset X': ('-1.26', 'µm'),
#  'Black Threshold': ('0.0', '%'),
#  'Nominal extractor V': ('5.40', 'kV'),
#  'Aperture at Y': ('1.3', '%'),
#  'Stage high M': ('0.000', 'mm'),
#  'EO Temp': ('24.0', '°C'),
#  'User Max EHT': ('30.00', 'kV'),
#  'CCD Illum.': ('85.0', '%'),
#  'FIB Beam Shift X': ('0.00', 'nm'),
#  'Scan Rotation': ('0.0', '°'),
#  'FIB Focus': '0.0',
#  'Fil I (Usermax)': ('4.000', 'A'),
#  'Mag Cal Actual Width': ('0.00', 'nm'),
#  'Defect ID': '0',
#  'Decl cal 1': '0.0000',
#  'Shift Amp Upper Offset Y': '0.0000',
#  'SmartImage Contrast': ('0.0', '%'),
#  'Stage vector Z': ('0.0', '%'),
#  'Argon Objective': ('0', 'V'),
#  'Frames to Int.': '0',
#  'Focus': ('4.022', 'mm'),
#  'Stage vector R': ('0.0', '%'),
#  'EHT Cal@24KV': ('24.08', 'kV'),
#  'Pa 9': ('0.00', 'nm'),
#  'V 6': ('0.00', 'nm'),
#  'Profile 1 X1': '33',
#  'HRRU No.': '0',
#  'FIB EHT Target': ('0.000', 'kV'),
#  'Humidity': ('0.0', '%'),
#  'ESB Grid Max': ('100', 'V'),
#  'Contrast D': ('41.5', '%'),
#  'Mill Item Elapsed Time': ('0', 'ms'),
#  'Beam deceleration Volts': ('0', 'V'),
#  'Calibrate Mag Lower Y': '0.0000',
#  'Da 4': ('0.00', 'nm'),
#  'FIB Condenser actual': ('0', 'V'),
#  'Argon Energy is': ('0', 'V'),
#  'Specimen I': ('0.0', 'pA'),
#  'Photo No.': '8273',
#  'Field Overlap': ('0.0', '%'),
#  'Spot signal': '0',
#  'Cursor Width': ('15.60', 'nm'),
#  'Profile Width 1': ('52.89', 'nm'),
#  'H 10': ('0.00', 'nm'),
#  'Stage Delta X': ('0.000', 'mm'),
#  'Compu. Tilt Error': '0.0000',
#  'FIB Drift X': ('0.00', 'nm'),
#  'Purge cycles': '2',
#  'C3 Lens I': ('962.37', 'mA'),
#  'EPD Low Limit': '0',
#  'C2 Rem': '0.0318',
#  'Slice Angle': ('0.0', '°'),
#  'Zoom Posn Y': '192',
#  'Pa 3': ('134.0', 'nm'),
#  'Clip Limit': '0',
#  'Liner cal @ 100V': ('100', 'V'),
#  'Pixel Size': ('918.3', 'pm'),
#  'Stage high Y': ('130.000', 'mm'),
#  'Collector Voltage': ('0.000', 'kV'),
#  'Argon Pixel Size': ('0.0', 'fm'),
#  'Mag Z0': '1.0000',
#  'Focus scan min': ('1', 'mm'),
#  'Extractor V Target': ('5.40', 'kV'),
#  'H 4': ('0.00', 'nm'),
#  'Image Pixel Size': ('918.3', 'pm'),
#  'FIB Aperture X Actual': '0',
#  'FIB Suppressor': ('0', 'V'),
#  'Drift Max Tries': '10',
#  'Beam Shift Align Y': ('0.00', 'nm'),
#  'Brightness': ('29.9', '%'),
#  'Fisheye quadriture': '1000',
#  'Gun Shift Y': ('0.0', '%'),
#  'Red.Raster Posn X': '706',
#  'Shift Amp Lower Gain X': '0.0000',
#  'Stage field size Y': ('0.000', 'mm'),
#  'Argon V Int is': ('0', 'V'),
#  'Contrast': ('41.5', '%'),
#  'Height': ('705.3', 'nm'),
#  'EHT Set minimum': ('0.010', 'kV'),
#  'Ext I Monitor': ('136.4', 'µA'),
#  'Aperture at X': ('8.5', '%'),
#  'Stage low M': ('0.000', 'mm'),
#  'FCF Setting': ('0.0', '%'),
#  'Db 4': ('0.', 'nm²'),
#  'FIB Stig Y': ('0.0', '%'),
#  'Frame Counter': '30016',
#  'Flood Gun Filament Actual': ('0', 'µA'),
#  'EP Target': ('10', 'Pa'),
#  'WD': ('4.022', 'mm'),
#  'HSync delay': ('0', 'ns'),
#  'Cycle Time': ('20.2', 'Secs'),
#  'FIB Gun Pressure': ('0.00e+000', 'mbar'),
#  'Shift Amp Upper Offset X': '0.0000',
#  'Compu. Tilt Offset': ('0.000', 'mm'),
#  'Stage vector Y': ('0.0', '%'),
#  'Argon Condenser is': ('0', 'V'),
#  'Frames to average': '1',
#  'Dual Mag Gain X': '670.65',
#  'Stage goto T': ('0.0', '°'),
#  'Chamber': ('0.00e+000', 'Pa'),
#  'EHT Cal@10KV': ('10.03', 'kV'),
#  'Pa 8': ('0.00', 'nm'),
#  'V 5': ('0.00', 'nm'),
#  'Stage Delta M': ('0.000', 'mm'),
#  'Print No.': '0',
#  'ESD Excitation': ('0.0', '%'),
#  'Peltier Target': ('20.0', '°C'),
#  'ESB Grid': ('100', 'V'),
#  'Contrast C': ('41.5', '%'),
#  'Mill Item Total Time': ('0', 'ms'),
#  'Stigmation Y': ('13.1', '%'),
#  'Pb 4': ('4.2', '°'),
#  'Calibrate Mag Lower X': '0.0000',
#  'Da 3': ('0.00', 'nm'),
#  'System Vacuum': ('3.02e-006', 'mbar'),
#  'Argon Energy': ('0', 'V'),
#  'Scan Y cal.': '0',
#  'Stage low T': ('0.0', '°'),
#  'Mag Gain Cal Y': '1000.00',
#  'H 9': ('0.00', 'nm'),
#  'Stage low R': ('-380.0', '°'),
#  'Aperture Align Y': ('1.3', '%'),
#  'FIB SEM Angle': ('54.0', '°'),
#  'EPD High Limit': '0',
#  'C2 Cal': '1.063',
#  'Slice Height': ('0.00', 'nm'),
#  'Zoom Posn X': '128',
#  'Pa 2': ('399.5', 'nm'),
#  'Tilt Align Y': ('0.0', '%'),
#  'FIB Min. Autoheat Current': ('0', 'µA'),
#  'Chamber Pressure Detailed': ('0.00e+000', 'Pa'),
#  'Stage high X': ('130.000', 'mm'),
#  'Collector Bias': ('400', 'V'),
#  'Focus scan max': ('40', 'mm'),
#  'Test Val': '0.0000',
#  'H 3': ('0.00', 'nm'),
#  'Db 2': ('0.', 'nm²'),
#  'FIB Aper.Align Y': '0',
#  'FIB Fil V target': ('0.0', 'V'),
#  'Drift Min Conf': ('50.0', '%'),
#  'Beam Shift Align X': ('0.00', 'nm'),
#  'Fisheye Orthog': ('0.0', '°'),
#  'Gun Shift X': ('0.0', '%'),
#  'Contrast B': ('41.5', '%'),
#  'Focus Rotation comp.': ('-0.009', 'kV'),
#  'Shift Amp Upper Gain Y': '0.0000',
#  'FIB Track WD Delta': ('0.00', 'nm'),
#  'Stage field size X': ('0.000', 'mm'),
#  'Argon V Int': ('0', 'V'),
#  'Offset A': ('0.0', '%'),
#  'Width': ('940.4', 'nm'),
#  'Mag Shift Cal Y': '0.0000',
#  'Pirani Pressure': ('0.00e+000', 'mbar'),
#  'Liner Tube': ('8.00', 'kV'),
#  'Stage goto M': ('0.000', 'mm'),
#  'Pb 7': ('0.0', '°'),
#  'V 10': ('0.00', 'nm'),
#  'Db 3': ('0.', 'nm²'),
#  'Flood Gun Serial Number': '0',
#  'FIB Stig X': ('0.0', '%'),
#  'Stage at M': ('0.000', 'mm'),
#  'Stage at Z': ('48.298', 'mm'),
#  'Stage at Y': ('50.7109', 'mm'),
#  'Fil I': ('2.250', 'A'),
#  'Stage at X': ('51.8077', 'mm'),
#  'EHT': ('5.00', 'kV'),
#  'Stage at T': ('0.0', '°'),
#  'Sample at Y': '0.0000',
#  'Stage at R': ('165.2', '°'),
#  'Sample at X': '0.0000',
#  'Time': '18:30:26',
#  'Date': ('1', 'Apr', '2015'),
#  'Version': ('V05.07.00.00', ':', '08-Jul-14'),
#  'User Text': (),
#  'File Name': 'Au-Gr_06.tif',
#  'Images': 'e:\\images\\alessia\\2015-04-01\\',
#  'User Name': 'USER',
#  'Sample ID': (),
#  'Serial No.': ('SUPRA', '40-25-40'),
#  'Operator': ()}

# %% [markdown]
# ### Duplicates
#
# How should this be implemented? Should I identify duplicates and delete them dynamically in the script? Or just use this func to identify what the duplicates are in HS and then always just delete those statically?
#
# Not even true duplicates, so need a way to differentiate
#
# HS Metadata:
# * `'ap_dc_shift_y': ('Aperture Align Y', 0.0, '%')`
# * `'ap_aperture_align_y': ('Aperture Align Y', 1.3, '%')`
#
# and
#
# *  `'ap_dc_shift_x': ('Aperture Align X', 0.0, '%')`
# * `'ap_aperture_align_x': ('Aperture Align X', -10.4, '%')`
#
# PIL Metadata:
# * `AP_DC_SHIFT_Y: Aperture Align Y =   0.0 %`
# * `AP_APERTURE_ALIGN_Y: Aperture Align Y =   1.3 %`
#
# and
#
# * `AP_DC_SHIFT_X: Aperture Align X =   0.0 %`
# * `AP_APERTURE_ALIGN_X: Aperture Align X = -10.4 %`

# %%
def ident_duplicates(key_list):
    duplicates = []
    unique_set = set()

    for item in key_list:
        if item in unique_set:
            duplicates.append(item)
        else:
            unique_set.add(item)
    return duplicates

print(ident_duplicates(hyperspy_keys))
print(ident_duplicates(PIL_keys))
# Out:
# ['Aperture Align X', 'Aperture Align Y']
# []
